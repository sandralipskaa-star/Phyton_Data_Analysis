# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month']=df['job_posted_date'].dt.strftime('%B')

# %%
#job country United States
df_us=df[df['job_country']=='United States']

# %%
#new column with month number
df_us['job_posted_month_num']=df_us['job_posted_date'].dt.month
df_us.drop(columns='no_month',inplace=True)
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_12028\2865922327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us['job_posted_month_num']=df_us['job_posted_date'].dt.month
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 #new column with month number
#       2 df_us['job_posted_month_num']=df_us['job_posted_date'].dt.month
# ----> 3 df_us.drop(columns='no_month',inplace=True)
#       4 df_us
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
# ...

# %%
df_us
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_us_pivot=df_us.pivot_table(index='job_posted_month', columns='job_title_short',aggfunc='size',values='job_posted_month_num')

# %%
df_us_pivot.reset_index(inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_us_pivot['month_no']=pd.to_datetime(df_us_pivot['job_posted_month'], format='%B').dt.month
df_us_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_us_pivot.set_index('month_no', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# month_no
# 4                          April               565              40
# 8                         August               903              39
# 12                      December               648              40
# 2                       February               447              24
# 1                        January               527              36
# 7                           July               581              39
# 6                           June               446              32
# 3                          March               438              19
# 5                            May               279              20
# 11                      November               719              36
# 10                       October               932              48
# 9                      September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# month_no
# ...

# %%
df_us_pivot=df_us_pivot.sort_index()

# %%
df_us_pivot.set_index('job_posted_month', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3=df_us['job_title_short'].value_counts().head(3).index

# %%
top_3=top_3.tolist()

# %%
df_us_pivot[top_3].plot(kind='line')
plt.title('Job Demand in the United States')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.legend(title='Job Title')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
