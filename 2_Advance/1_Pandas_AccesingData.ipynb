# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.loc[:,['salary_rate','salary_hour_avg','salary_year_avg']].dropna(subset='salary_rate')
#2 options using slice : shows all columns between or in [] as a list to show particular columns
#or without loc : df[['salary_rate','salary_hour_avg','salary_year_avg']].dropna(subset='salary_rate')
#df.loc[:,'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_hour_avg  salary_year_avg
# 28            year              NaN         109500.0
# 43            hour             97.5              NaN
# 51            hour             72.5              NaN
# 77            year              NaN         140000.0
# 92            year              NaN         120000.0
# ...            ...              ...              ...
# 785624        year              NaN         139216.0
# 785641        year              NaN         150000.0
# 785648        year              NaN         221875.0
# 785682        year              NaN         157500.0
# 785692        year              NaN         157500.0
#
# [33067 rows x 3 columns]
