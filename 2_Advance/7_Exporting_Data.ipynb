# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_posted_month']=df['job_posted_date'].dt.strftime('%b')
months=df['job_posted_month'].unique()

dict_months={month:df[df['job_posted_month'] == month] for month in months}

# %%
q1=pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']],ignore_index=True)

# %%
q1.head().to_clipboard(sep=',')

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
# 0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",Jan
# 1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,,,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",Jan
# 2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,,,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",Jan
# 3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,,,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",Jan
# 4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,,,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",Jan

# %%
q1.to_csv('q1_jobs.csv')

# %%
pd.read_csv('q1_jobs.csv',index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-01-14 13:18:07                  False                 False
# 1       2023-01-31 13:53:38                  False                 False
# 2       2023-01-25 13:24:01                  False                 False
# 3       2023-01-28 13:07:30                  False                  True
# 4       2023-01-03 23:02:27                  False                 False
# ...                     ...                    ...                   ...
# 220479  2023-03-13 06:16:16                  False                 False
# 220480  2023-03-12 06:18:18                  False                 False
# 220481  2023-03-12 06:32:36                  False                 False
# 220482  2023-03-12 06:32:15                  False                 False
# 220483  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %%
q1.to_excel('q1_jobs.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 q1.to_excel('q1_jobs.xlsx',index=False)
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)   2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\io\formats\excel.py:962, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
# --> 962         writer.close()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\worksheet\_writer.py:359, in openpyxl.worksheet._writer.WorksheetWriter.write()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\worksheet\_writer.py:123, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\worksheet\_writer.py:125, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\worksheet\_writer.py:135, in openpyxl.worksheet._writer.WorksheetWriter.write_row()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\worksheet\_writer.py:147, in openpyxl.worksheet._writer.WorksheetWriter.write_row()
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\openpyxl\cell\_writer.py:86, in etree_write_cell(xf, worksheet, cell, styled)
#      83     if value is not None:
#      84         cell_content.text = safe_string(value)
# ---> 86 xf.write(el)
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\et_xmlfile\xmlfile.py:120, in _IncrementalFileWriter.write(self, arg)
#     118     default_ns_attr_prefix = None
#     119     uri_to_prefix = {}
# --> 120 incremental_tree._serialize_ns_xml(
#     121     self._file,
#     122     arg,
#     123     nsmap_scope=nsmap_scope,
#     124     global_nsmap=self.global_nsmap,
#     125     short_empty_elements=True,
#     126     is_html=self.is_html,
#     127     is_root=is_root,
#     128     uri_to_prefix=uri_to_prefix,
#     129     default_ns_attr_prefix=default_ns_attr_prefix,
#     130 )
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\et_xmlfile\incremental_tree.py:613, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     566 def _serialize_ns_xml(
#     567     write,
#     568     elem,
#    (...)    577     **kwargs,
#     578 ):
#     579     """Serialize an element or tree using 'write' for output.
#     580
#     581     Args:
#    (...)    605             New prefix -> uri mapping to be applied to this element.
#     606     """
#     607     (
#     608         tag,
#     609         nsmap_scope,
#     610         default_ns_attr_prefix,
#     611         uri_to_prefix,
#     612         next_remains_root,
# --> 613     ) = write_elem_start(
#     614         write,
#     615         elem,
#     616         nsmap_scope,
#     617         global_nsmap,
#     618         short_empty_elements,
#     619         is_html,
#     620         is_root,
#     621         uri_to_prefix,
#     622         default_ns_attr_prefix,
#     623         new_nsmap=new_nsmap,
#     624     )
#     625     for e in elem:
#     626         _serialize_ns_xml(
#     627             write,
#     628             e,
#    (...)    636             new_nsmap=None,
#     637         )
#
# File c:\Users\sandr\anaconda3\envs\py311\Lib\site-packages\et_xmlfile\incremental_tree.py:539, in write_elem_start(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     537         write("".join([f' {k}="{ET._escape_attrib_html(v)}"' for k, v in item_parts]))
#     538     else:
# --> 539         write("".join([f' {k}="{ET._escape_attrib(v)}"' for k, v in item_parts]))
#     540 if is_html:
#     541     write(">")
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
